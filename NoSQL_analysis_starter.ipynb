# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
collection_list = db.list_collection_names()

# %%
# assign the collection to a variable
establishments = db['establishments']
print("Collections in the database:")
for collection in collection_list:
    print(f"- {collection}")
# Out:
# Collections in the database:
# - establishments

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print(f"Number of establishments with hygiene score 20: {count}")

# Display the first document in the results using pprint
print("\nFirst matching establishment:")
first_doc = establishments.find_one(query)
pprint(first_doc)
# Out:
# Number of establishments with hygiene score 20: 82
#
# First matching establishment:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67ebf1085126812def35ba2b'),
#  'geocode': {'latitude': '50.769705', 'longitude': '0.27694'},
# ...

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(list(establishments.find(query)))

# Display the number of rows in the DataFrame
print(f"Number of rows in DataFrame: {len(df)}")

# Display the first 10 rows of the DataFrame
display(df.head(10))
# Out:
# Number of rows in DataFrame: 82
#                         _id   FHRSID  ChangesByServerID  \
# 0  67ebf1085126812def35ba2b   110681                  0
# 1  67ebf1085126812def35bdbe   612039                  0
# 2  67ebf1085126812def35c0b5   730933                  0
# 3  67ebf1085126812def35c2a5   172735                  0
# 4  67ebf1085126812def35c2b1   172953                  0
# 5  67ebf1085126812def35cc50   512854                  0
# 6  67ebf1085126812def35ce6f  1537089                  0
# 7  67ebf1085126812def35e39b   155648                  0
# 8  67ebf1085126812def35e7e4  1012883                  0
# 9  67ebf1085126812def35eff7   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {
    "LocalAuthorityName": {"$regex": "London", "$options": "i"},
    "RatingValue": {"$gte": 4}
}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print(f"Number of London establishments with rating ≥4: {count}")

# Display the first document in the results using pprint
print("\nFirst matching establishment:")
first_doc = establishments.find_one(query)
pprint(first_doc)

# Convert to Pandas DataFrame and display results
df = pd.DataFrame(list(establishments.find(query)))
display(df[['BusinessName', 'LocalAuthorityName', 'RatingValue', 'scores']].head())
# Out:
# Number of London establishments with rating ≥4: 66
#
# First matching establishment:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67ebf1085126812def35d441'),
# ...

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(list(establishments.find(query)))

# Display the number of rows in the DataFrame
print(f"Number of establishments found: {len(df)}")

# Display the first 10 rows of the DataFrame
display(df.head(10))
# Out:
# Number of establishments found: 66
#                         _id   FHRSID  ChangesByServerID  \
# 0  67ebf1085126812def35d441   621707                  0
# 1  67ebf1085126812def35d76a  1130836                  0
# 2  67ebf1085126812def35e2b7   293783                  0
# 3  67ebf1085126812def35f0b6  1315095                  0
# 4  67ebf1085126812def35f0b7   294474                  0
# 5  67ebf1085126812def35f7bf   294900                  0
# 6  67ebf1095126812def3618ce   293756                  0
# 7  67ebf1095126812def361c9e   878523                  0
# 8  67ebf1095126812def361cb0   294606                  0
# 9  67ebf1095126812def361cb1   295107                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
print(establishments.count_documents({"RatingValue": 5}))
print(establishments.count_documents({
    "latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
    "longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search}
}))
# Out:
# 51632
# 0

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {
    "latitude": {
        "$gte": latitude - degree_search,
        "$lte": latitude + degree_search
    },
    "longitude": {
        "$gte": longitude - degree_search,
        "$lte": longitude + degree_search
    },
    "RatingValue": 5
}

sort = [("scores.Hygiene", 1)] 

limit = 5

# Print the results
results = list(establishments.find(query).sort(sort).limit(limit))
for i, result in enumerate(results, 1):
    print(f"{i}. {result['BusinessName']}")
    print(f"   Hygiene: {result['scores']['Hygiene']}")
    print(f"   Location: {result['geocode']['latitude']}, {result['geocode']['longitude']}")
    print(f"   Address: {result.get('AddressLine1', '')}, {result.get('AddressLine2', '')}")
    print(f"   Business Type: {result.get('BusinessType', '')}\n")
# Out:
# 1. Howe and Co Fish and Chips - Van 17
#    Hygiene: 0
#    Location: 51.4875335693359, 0.0925370007753372
#    Address: Restaurant And Premises 107A Plumstead High Street,
#    Business Type: Mobile caterer
#
# 2. Lumbini Grocery Ltd T/A Al-Iman
#    Hygiene: 0
#    Location: 51.4871632, 0.0916256
#    Address: 17 Lakedale Road,
#    Business Type: Retailers - other
#
# 3. Atlantic Fish Bar
#    Hygiene: 0
#    Location: 51.4867296, 0.0912164
#    Address: 35 Lakedale Road,
#    Business Type: Takeaway/sandwich shop
#
# 4. Iceland
#    Hygiene: 0
#    Location: 51.4871482849121, 0.0924199968576431
#    Address: 144 - 146 Plumstead High Street,
#    Business Type: Retailers - supermarkets/hypermarkets
#
# 5. Volunteer
#    Hygiene: 0
#    Location: 51.4873437, 0.09208
#    Address: 130 - 132 Plumstead High Street,
#    Business Type: Pub/bar/nightclub

# %%
# Convert result to Pandas DataFrame
df = pd.DataFrame(list(
    establishments.find(query).limit(10)
))

# Display DataFrame info
display(df.head())
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  67ebf1095126812def361235  1069652                  0
# 1  67ebf1095126812def361261   695223                  0
# 2  67ebf1095126812def361270  1380578                  0
# 3  67ebf1095126812def361289   694609                  0
# 4  67ebf1095126812def3612a0   694478                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000206841   TIWA N TIWA African Restaurant Ltd
# 1             PI/000178842                              Iceland
# 2                    14425  Howe and Co Fish and Chips - Van 17
# 3             PI/000116619                            Volunteer
# 4             PI/000086506                    Atlantic Fish Bar
#
#                             BusinessType  BusinessTypeID  \
# 0                Restaurant/Cafe/Canteen               1
# 1  Retailers - supermarkets/hypermarkets            7840
# 2                         Mobile caterer            7846
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
pipeline = [
    
# 1. Matches establishments with a hygiene score of 0
    {"$match": {"scores.Hygiene": 0}},

# 2. Groups the matches by Local Authority
    {"$group": {
        "_id": "$LocalAuthorityName",
        "count": {"$sum": 1}
        }},
    
# 3. Sorts the matches from highest to lowest
    {"$sort": {"count": -1}},

]

results = list(establishments.aggregate(pipeline))
    
# Print the number of documents in the result
print(f"Number of Local Authorities with hygiene score 0 establishments: {len(results)}")

# Print the first 10 results
print("\nTop 10 Local Authorities by count (highest to lowest):")
for i, result in enumerate(results[:10], 1):
    print(f"{i}. {result['_id']}: {result['count']} establishments")
# Out:
# Number of Local Authorities with hygiene score 0 establishments: 55
#
# Top 10 Local Authorities by count (highest to lowest):
# 1. Thanet: 2260 establishments
# 2. Greenwich: 1764 establishments
# 3. Maidstone: 1426 establishments
# 4. Newham: 1422 establishments
# 5. Swale: 1372 establishments
# 6. Chelmsford: 1360 establishments
# 7. Medway: 1344 establishments
# 8. Bexley: 1214 establishments
# 9. Southend-On-Sea: 1172 establishments
# 10. Tendring: 1084 establishments

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results).rename(columns={"_id": "LocalAuthority"})

# Display the number of rows in the DataFrame
print(f"Number of rows in DataFrame: {len(df)}")

# Display the first 10 rows of the DataFrame
print("\nFirst 10 rows:")
display(df.head(10))
# Out:
# Number of rows in DataFrame: 55
#
# First 10 rows:
#     LocalAuthority  count
# 0           Thanet   2260
# 1        Greenwich   1764
# 2        Maidstone   1426
# 3           Newham   1422
# 4            Swale   1372
# 5       Chelmsford   1360
# 6           Medway   1344
# 7           Bexley   1214
# 8  Southend-On-Sea   1172
# 9         Tendring   1084
